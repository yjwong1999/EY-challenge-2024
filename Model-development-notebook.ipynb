# %% [markdown]
# # 0. Prerequisites

# %% [markdown]
# ## Code Structure
# #### Before unzip
# ```
# Double-Y
# ├── our-best-runs                       (proof of our experiment that yields the highest mAP)
# │   ├── detect
# │   │   ├── predict
# │   │   ├── train
# ├── additional-dataset.zip              (additional dataset)
# ├── best-trained-model.pt               (best trained model which we used for submission, mAP 0.51)
# ├── challenge_1_submission_images.zip   (just the zip file of EY Challenge Phase 1 test images)
# ├── labelled-dataset.zip                (labelled dataset)
# ├── Model-development-notebook.ipynb    (to train the model)
# ├── requirements.txt                    (dependencies requirement)
# ├── Validation-notebook.ipynb           (for Phase 1 submission)
# ```

# %%
import os
import zipfile

def unzip_folder(zip_filepath, dest_dir):
    with zipfile.ZipFile(zip_filepath, 'r') as zip_ref:
        zip_ref.extractall(dest_dir)
    print(f'The zip file {zip_filepath} has been extracted to the directory {dest_dir}')

# create dataset directory
os.makedirs('dataset')

# Unzip additional dataset
zip_file = './additional-dataset.zip'
unzip_directory = './dataset/additional-dataset'
if not os.path.isdir(unzip_directory):
    unzip_folder(zip_file,unzip_directory)

# Unzip labelled dataset
zip_file = './labelled-dataset.zip'
unzip_directory = './dataset/labelled-dataset'
if not os.path.isdir(unzip_directory):
    unzip_folder(zip_file,unzip_directory)
# Out:
# The zip file ./additional-dataset.zip has been extracted to the directory ./dataset/additional-dataset
# The zip file ./labelled-dataset.zip has been extracted to the directory ./dataset/labelled-dataset

# %% [markdown]
# #### After unzip
# ```
# Double-Y
# ├── dataset                             (to store all datasets)
# │   ├── additional-dataset              (to store additional datasets)
# │   │   ├── msft-puerto-rico
# │   ├── labelled-dataset                (to store all laballed challange datasets)
# │   │   ├── crowd-sourced
# │   │   ├── self-annotated
# │   │   ├── experts
# ├── our-best-runs                       (proof of our experiment that yields the highest mAP)
# │   ├── detect
# │   │   ├── predict
# │   │   ├── train
# ├── additional-dataset.zip              (additional dataset)
# ├── best-trained-model.pt               (best trained model which we used for submission, mAP 0.51)
# ├── challenge_1_submission_images.zip   (just the zip file of EY Challenge Phase 1 test images)
# ├── labelled-dataset.zip                (labelled dataset)
# ├── Model-development-notebook.ipynb    (to train the model)
# ├── requirements.txt                    (dependencies requirement)
# ├── Validation-notebook.ipynb           (for Phase 1 submission)
# ```

# %% [markdown]
# ### Install dependencies

# %%
# Install YOLOv8
# !pip install ultralytics==8.0.196

# Import required libraries
from IPython import display
display.clear_output()

# %% [markdown]
# # MODULE 1: Pretraining
#
# In this module, we will use [Microsoft Building Footprints (BF)](https://planetarycomputer.microsoft.com/dataset/ms-buildings#overview) dataset to train a YOLOv8n model. This model will serve as pretrained model, which will be fine-tuned for EY Challenge 2024 dataset in Module 2.
#
# The pipeline for Module 1 is shown below:
# 1. Get **Microsoft-Building** dataset (only Puerto Rico region) from Module 0
# 2. **Transfer Learning**: Use YOLOv8 (with COCO weights) on the Puerto Rico dataset

# %%
from ultralytics import YOLO

# yaml file of the Puerto Rico dataset
yaml_file = "dataset/additional-dataset/msft-puerto-rico/data.yaml"

# use COCO pretrained YOLOv8 models for transfer learning
model = YOLO("yolov8n.pt")
model.train(data=yaml_file, epochs=80, imgsz=512, plots=True)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████████████████████████████████| 6.23M/6.23M [00:00<00:00, 54.0MB/s]
# New https://pypi.org/project/ultralytics/8.1.27 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.8.10 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2070 Super, 7974MiB)
# engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=dataset/additional-dataset/msft-puerto-rico/data.yaml, epochs=80, patience=50, batch=16, imgsz=512, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751507  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# Model summary: 225 layers, 3011043 parameters, 3011027 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /home/tham/Desktop/delete/EY/dataset/additional-dataset/msft-pue
# train: New cache created: /home/tham/Desktop/delete/EY/dataset/additional-dataset/msft-puerto-rico/train/labels.cache
# val: Scanning /home/tham/Desktop/delete/EY/dataset/additional-dataset/msft-puert
# val: New cache created: /home/tham/Desktop/delete/EY/dataset/additional-dataset/msft-puerto-rico/valid/labels.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 512 train, 512 val
# Using 8 dataloader workers
# Logging results to runs/detect/train
# Starting training for 80 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/80      1.48G       2.15      2.434      1.832        173        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.441       0.34      0.321      0.128
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/80      1.46G      1.969      2.003      1.664        132        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.462       0.39      0.372      0.153
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/80      1.47G      1.971      1.928      1.668        138        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.451      0.392      0.333       0.13
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/80      1.59G      1.979      1.909      1.684        121        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.504      0.439       0.42      0.179
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/80      1.56G       1.92      1.816      1.648        123        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.547      0.458      0.451      0.199
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/80      1.49G      1.881      1.739      1.622        166        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094        0.6      0.478      0.497      0.226
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/80      1.45G      1.846      1.686      1.593        117        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.631      0.501      0.527      0.247
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/80      1.51G      1.823      1.651      1.579        102        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.597      0.504      0.509      0.237
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/80      1.46G      1.795      1.608      1.557        136        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.641      0.516      0.537      0.259
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/80      1.58G      1.784      1.583      1.549        196        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.643      0.512      0.541      0.255
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/80       1.5G       1.76      1.546      1.531        176        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.626      0.521      0.534      0.261
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/80      1.53G      1.748      1.514      1.517        152        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.666      0.529      0.563      0.274
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/80      1.54G       1.73      1.502      1.509        141        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.677      0.541       0.58      0.283
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/80      1.42G      1.721       1.48      1.503        117        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.676      0.546      0.587      0.288
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/80      1.46G      1.711      1.465      1.494        128        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.684      0.555      0.595      0.299
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/80      1.53G      1.701      1.447      1.489        163        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.701      0.554      0.599      0.303
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/80      1.49G      1.692      1.428      1.476        113        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.692      0.572      0.608      0.307
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/80      1.45G      1.679      1.418      1.474        133        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.692      0.572      0.607      0.306
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/80      1.54G      1.669      1.402      1.464        119        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.695      0.566       0.61       0.31
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/80      1.46G      1.659      1.383      1.458         98        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.708      0.572      0.616      0.315
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/80       1.5G      1.652      1.372      1.452        158        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.714      0.572      0.617      0.318
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/80      1.54G      1.641      1.359      1.446        157        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.706       0.58      0.623      0.322
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/80      1.52G      1.635      1.357      1.444        101        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.711      0.579      0.622      0.321
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/80      1.57G       1.63      1.346      1.439        129        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.715       0.58      0.625      0.326
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/80      1.47G      1.635      1.341      1.441        120        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.714      0.581      0.627      0.329
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/80      1.53G      1.615      1.325      1.431        188        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.707       0.59       0.63       0.33
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/80      1.49G      1.609      1.312      1.423        147        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.717      0.594      0.633      0.331
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/80      1.53G      1.604      1.305       1.42        109        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.712        0.6      0.635      0.333
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/80      1.42G      1.595      1.291      1.414        125        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.719      0.595      0.637      0.336
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/80       1.5G      1.594      1.288      1.414        155        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.719      0.594      0.636      0.335
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/80      1.58G      1.583      1.279      1.408        143        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.718      0.598       0.64      0.338
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/80      1.53G      1.578      1.265      1.402        143        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.726      0.599      0.644       0.34
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/80      1.42G      1.572      1.262        1.4        161        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.727      0.607      0.645       0.34
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/80       1.5G      1.567      1.251      1.396        145        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.718      0.602      0.641      0.339
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/80      1.42G      1.555      1.241       1.39         88        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.723      0.603      0.643      0.341
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/80       1.5G      1.559      1.245      1.391        175        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.724      0.601      0.644      0.343
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/80      1.55G      1.552      1.233      1.386        131        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.723      0.605      0.646      0.343
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/80      1.58G      1.544      1.225       1.38        145        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094       0.73      0.606       0.65      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/80      1.47G      1.535      1.211      1.375        145        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.732      0.607       0.65      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/80      1.54G      1.535      1.211      1.376        121        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094       0.73      0.611      0.651      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/80      1.53G      1.531      1.201      1.372        119        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.727      0.608       0.65      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/80      1.58G      1.526      1.194      1.367        165        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.738      0.603       0.65      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/80      1.54G      1.514      1.184      1.364        157        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.728      0.614      0.652      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/80      1.55G      1.516      1.185      1.363        120        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.736      0.607      0.653      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/80      1.58G       1.51      1.181      1.362         96        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.733      0.608      0.651      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/80      1.43G      1.509      1.169      1.357        149        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.728      0.612      0.651      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/80      1.55G      1.496      1.155      1.349        136        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.731      0.614      0.654      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/80       1.5G      1.497      1.159      1.349        153        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094       0.73      0.612      0.655      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/80      1.54G      1.495       1.16       1.35        110        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.736      0.608      0.656      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/80      1.53G      1.485      1.138      1.343        160        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.731      0.612      0.656      0.348
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       51/80      1.46G      1.475      1.139      1.336        120        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.736      0.609      0.656      0.349
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       52/80      1.58G      1.469      1.128      1.332        130        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.731      0.611      0.656      0.349
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       53/80      1.46G      1.465      1.127      1.333        163        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.731      0.611      0.656      0.348
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       54/80      1.43G      1.466       1.12      1.332        116        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.728      0.615      0.657      0.348
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       55/80      1.42G      1.457      1.112      1.324        151        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.728      0.614      0.656      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       56/80      1.47G      1.456      1.113      1.323         59        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.728      0.617      0.657      0.348
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       57/80      1.49G      1.444      1.094      1.317        146        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.729      0.617      0.657      0.348
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       58/80      1.54G      1.445      1.093      1.316        121        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.729      0.616      0.658      0.348
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       59/80      1.46G      1.437       1.09      1.312        170        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.736      0.611      0.657      0.348
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       60/80       1.5G      1.432       1.08      1.309        108        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.736      0.609      0.657      0.348
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       61/80      1.42G      1.424      1.076      1.306         87        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.738      0.607      0.657      0.348
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       62/80       1.5G      1.424      1.075      1.306        113        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094       0.74      0.605      0.657      0.348
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       63/80      1.49G      1.421      1.067        1.3        138        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.741      0.605      0.656      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       64/80       1.5G      1.415      1.057      1.297        182        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.744      0.602      0.656      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       65/80      1.45G      1.403      1.047      1.292        155        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.741      0.604      0.656      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       66/80      1.46G      1.401      1.044       1.29        103        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.743      0.603      0.656      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       67/80      1.59G      1.395      1.037      1.288        150        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.743      0.604      0.656      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       68/80       1.5G      1.395      1.042      1.287        129        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.744      0.603      0.656      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       69/80      1.54G      1.387      1.035      1.285        168        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.741      0.606      0.656      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       70/80      1.52G      1.379      1.023      1.278        141        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.734      0.611      0.656      0.346
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       71/80      1.55G      1.358     0.9582      1.288         64        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.733      0.611      0.655      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       72/80      1.55G      1.339     0.9375      1.278        127        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094       0.73      0.614      0.655      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       73/80      1.42G      1.326     0.9279      1.271         45        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.731      0.613      0.655      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       74/80      1.46G      1.314     0.9175      1.266         88        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.729      0.614      0.655      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       75/80      1.55G      1.306     0.9102      1.259         89        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.729      0.613      0.654      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       76/80      1.55G      1.298     0.9023      1.257         78        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.729      0.613      0.654      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       77/80      1.45G      1.286     0.8923       1.25         61        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094       0.73      0.612      0.654      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       78/80      1.55G      1.285     0.8907       1.25         57        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094       0.73      0.613      0.654      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       79/80      1.42G      1.277     0.8831      1.245        104        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094       0.73      0.613      0.653      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       80/80      1.46G      1.269     0.8738      1.239         79        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.729      0.614      0.653      0.344
#
# 80 epochs completed in 2.170 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 6.2MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 6.2MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.0.196 🚀 Python-3.8.10 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2070 Super, 7974MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094       0.73      0.611      0.656      0.349
# Speed: 0.1ms preprocess, 1.0ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to runs/detect/train
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7fe4a1e98f40>
# fitness: 0.3794640517129215
# keys: ['metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)']
# maps: array([    0.34873])
# names: {0: 'buildings'}
# plot: True
# results_dict: {'metrics/precision(B)': 0.7300005628785157, 'metrics/recall(B)': 0.611353279175748, 'metrics/mAP50(B)': 0.6560390101806547, 'metrics/mAP50-95(B)': 0.3487335007720623, 'fitness': 0.3794640517129215}
# save_dir: PosixPath('runs/detect/train')
# speed: {'preprocess': 0.10780662353289987, 'inference': 0.9868631227767108, 'loss': 0.00045847466751446493, 'postprocess': 0.7253172070026692}

# %%
# Validation

# !yolo task=detect mode=val model=runs/detect/train/weights/best.pt data={yaml_file}
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.8.10 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2070 Super, 7974MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /home/tham/Desktop/delete/EY/dataset/additional-dataset/msft-puert
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1623      10094      0.731      0.611      0.656      0.348
# Speed: 0.2ms preprocess, 1.7ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# rename "runs" directory to "pretrained"
import os
os.rename('runs', 'pretrained')

# %% [markdown]
# # MODULE 2: Fine-tune on EY Challenge 2024 dataseet
#
# In this module, we will use the pretrained model from  Module 1, and fine-tune it using EY Challenge 2024 dataset.
#
# The pipeline for Module 2 is shown below:
# 1. A **fine-grained dataset** is prepared. Specifically, we go through the post-event dataset, and find relevant images that are suitable for training. Notably, we keep in mind of the potential class imbalanced issue while collecting the relevant images. Then, we annotate the dataset.
# 2. **Transfer Learning**: Use pretrained YOLOv8 (from Module 1) on the fine-grained dataset
#
# Note that without transfer learning using Module 1's YOLOv8, there is a high chance of overfitting on the actual test data provided by the EY Challenge 2024 dataset. You might get a better train mAP, but it does not actually reflect the mAP on the test set.

# %%
from ultralytics import YOLO
import os 

# yaml file of the training dataset
yaml_file = "dataset/labelled-dataset/crowd-sourced/data.yaml"

# use pretrained model (via Puerto Rioo dataset) + fine tune on crowd-sourced dataset
model = YOLO(f"{os.getcwd()}/pretrained/detect/train/weights/best.pt")
model.train(data=yaml_file, epochs=50, imgsz=512, plots=True)
# Out:
# New https://pypi.org/project/ultralytics/8.1.27 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.8.10 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2070 Super, 7974MiB)
# engine/trainer: task=detect, mode=train, model=/home/tham/Desktop/delete/EY/pretrained/detect/train/weights/best.pt, data=dataset/labelled-dataset/crowd-sourced/data.yaml, epochs=50, patience=50, batch=16, imgsz=512, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Overriding model.yaml nc=1 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752092  ultralytics.nn.modules.head.Detect           [4, [64, 128, 256]]
# Model summary: 225 layers, 3011628 parameters, 3011612 gradients, 8.2 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /home/tham/Desktop/delete/EY/dataset/labelled-dataset/crowd-sour
# train: WARNING ⚠️ /home/tham/Desktop/delete/EY/dataset/labelled-dataset/crowd-sourced/train/images/tile_57_101_jpg.rf.10263dcc3eb78408479d4cf395c4d087.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/tham/Desktop/delete/EY/dataset/labelled-dataset/crowd-sourced/train/images/tile_57_101_jpg.rf.803a18bd00cf5c1c419655eebb0c7c4c.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/tham/Desktop/delete/EY/dataset/labelled-dataset/crowd-sourced/train/images/tile_57_101_jpg.rf.8f08feb14e527498d8d2fafa26e2d4e0.jpg: 1 duplicate labels removed
# train: New cache created: /home/tham/Desktop/delete/EY/dataset/labelled-dataset/crowd-sourced/train/labels.cache
# val: Scanning /home/tham/Desktop/delete/EY/dataset/labelled-dataset/crowd-source
# val: New cache created: /home/tham/Desktop/delete/EY/dataset/labelled-dataset/crowd-sourced/valid/labels.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 512 train, 512 val
# Using 8 dataloader workers
# Logging results to runs/detect/train
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      1.76G      2.325      3.734      1.663         90        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.902     0.0682      0.335      0.181
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50       1.8G      1.773      2.837      1.275         26        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.457      0.311      0.306       0.17
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      1.82G      1.658      2.175      1.236         23        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.223      0.478      0.266      0.142
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      1.72G      1.591      1.917      1.224         19        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.265      0.462      0.355      0.205
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      1.78G      1.538      1.767      1.212         17        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.279      0.653      0.371      0.224
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      1.64G      1.502      1.709      1.208         14        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212       0.33      0.504      0.437      0.257
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      1.67G      1.506      1.648      1.204         26        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.371      0.531      0.405       0.24
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      1.77G       1.45      1.583      1.198          8        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.463      0.503      0.464      0.278
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50       1.7G      1.451      1.516      1.195         15        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.495      0.419      0.451      0.268
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      1.75G      1.446      1.478      1.186         14        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.393      0.534      0.486      0.288
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      1.68G      1.432      1.487      1.183          5        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.561      0.445      0.504      0.308
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      1.71G      1.385      1.421      1.179         18        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.513      0.498      0.508      0.293
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      1.69G      1.439      1.408       1.18         18        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.441      0.591      0.492      0.279
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      1.76G      1.405       1.41      1.172          8        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.463      0.477      0.485      0.296
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      1.69G       1.44      1.391      1.178         37        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.469      0.556      0.494      0.293
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      1.78G      1.372      1.353      1.155         13        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.594      0.492      0.516      0.314
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      1.72G       1.38      1.374      1.156          4        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.565      0.555      0.546      0.325
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      1.78G      1.405      1.353      1.148         49        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.515      0.479      0.499      0.316
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      1.71G      1.352      1.333      1.155          6        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.504      0.599      0.536      0.331
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      1.78G      1.361      1.278      1.137         32        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.491      0.541      0.495      0.293
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      1.67G      1.371      1.316      1.177          6        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.426       0.59      0.514      0.303
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      1.73G      1.391      1.272      1.158         15        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.558      0.479      0.528      0.311
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      1.78G      1.339      1.294      1.131          3        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212       0.43      0.549      0.501        0.3
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      1.73G      1.318      1.244      1.122         52        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.427       0.55      0.462      0.276
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      1.75G      1.311       1.22      1.125         26        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.486      0.527      0.524      0.311
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      1.83G      1.353       1.21      1.143         12        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.446      0.608      0.502      0.305
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      1.71G      1.324      1.173      1.131          8        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.528      0.512      0.531      0.319
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      1.79G      1.323      1.199      1.133         15        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.426      0.577      0.491      0.296
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50       1.7G      1.307      1.179      1.117         14        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.544      0.471      0.508      0.306
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      1.68G      1.326      1.153      1.127         15        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.482      0.523      0.507      0.302
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      1.57G      1.333      1.204      1.119         22        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.539       0.51      0.541      0.317
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      1.72G      1.322      1.161      1.138         14        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.544      0.512      0.504      0.294
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      1.85G      1.264      1.124      1.094         10        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.481      0.561      0.491        0.3
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      1.58G      1.304      1.122      1.114         49        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.535      0.524       0.54       0.32
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      1.82G      1.289      1.126      1.107         36        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212       0.49      0.561      0.518      0.314
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      1.76G      1.291      1.136      1.122          8        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.475      0.522      0.487      0.306
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      1.74G      1.267      1.098      1.107         14        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.437      0.632      0.514      0.315
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      1.72G      1.287      1.079      1.117         22        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.439      0.585      0.515      0.311
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      1.79G      1.283      1.103      1.118         22        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.552      0.456      0.521      0.305
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      1.73G      1.278      1.176       1.12          5        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212       0.54      0.468      0.506      0.297
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      1.68G      1.253      1.113      1.103         12        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.513      0.507       0.52      0.307
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      1.57G      1.233      1.067      1.106         21        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.511      0.523      0.489      0.286
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      1.53G      1.231      1.038      1.109         10        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.498      0.508      0.507      0.306
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      1.57G        1.2      1.019      1.087          7        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.557      0.463       0.51      0.293
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      1.59G      1.205      1.004      1.088         26        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.492      0.449      0.479      0.287
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      1.65G      1.199     0.9972      1.094          5        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.545       0.47      0.499      0.299
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      1.64G      1.185     0.9776      1.083          6        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.511      0.534      0.526      0.312
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      1.63G      1.194     0.9674      1.085         25        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212       0.49      0.496      0.506      0.306
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      1.62G      1.246     0.9863      1.112          7        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.428      0.554      0.501      0.305
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      1.64G      1.218     0.9787      1.094         22        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.434      0.551      0.507      0.309
#
# 50 epochs completed in 0.037 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 6.2MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 6.2MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.0.196 🚀 Python-3.8.10 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2070 Super, 7974MiB)
# Model summary (fused): 168 layers, 3006428 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         12        212      0.506      0.599      0.537      0.331
#                      0         12        132      0.667      0.826      0.812      0.489
#                      1         12         11       0.57      0.605      0.579      0.399
#                      2         12         60      0.368      0.633      0.406      0.223
#                      3         12          9      0.418      0.333      0.351      0.212
# Speed: 0.1ms preprocess, 1.1ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to runs/detect/train
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0, 1, 2, 3])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7fe537c02f40>
# fitness: 0.3513725514503218
# keys: ['metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)']
# maps: array([     0.4892,      0.3992,     0.22253,     0.21205])
# names: {0: '0', 1: '1', 2: '2', 3: '3'}
# plot: True
# results_dict: {'metrics/precision(B)': 0.5059302947682462, 'metrics/recall(B)': 0.5993382587132587, 'metrics/mAP50(B)': 0.5370082715449616, 'metrics/mAP50-95(B)': 0.3307463603286952, 'fitness': 0.3513725514503218}
# save_dir: PosixPath('runs/detect/train')
# speed: {'preprocess': 0.1164873441060384, 'inference': 1.0650356610616047, 'loss': 0.0014106432596842449, 'postprocess': 1.4220277468363445}

# %%
# rename
import os
os.rename('runs', 'fine-tune-on-crowd-sourced')

# %%
from ultralytics import YOLO

# yaml file of the training dataset
yaml_file = "dataset/labelled-dataset/self-annotated/data.yaml"

# use COCO pretrained YOLOv8 models from Module 1 for transfer learning
model = YOLO(f"{os.getcwd()}/fine-tune-on-crowd-sourced/detect/train/weights/best.pt")
model.train(data=yaml_file, epochs=20, imgsz=512, plots=True)
# Out:
# New https://pypi.org/project/ultralytics/8.1.27 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.8.10 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2070 Super, 7974MiB)
# engine/trainer: task=detect, mode=train, model=/home/tham/Desktop/delete/EY/fine-tune-on-crowd-sourced/detect/train/weights/best.pt, data=dataset/labelled-dataset/self-annotated/data.yaml, epochs=20, patience=50, batch=16, imgsz=512, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752092  ultralytics.nn.modules.head.Detect           [4, [64, 128, 256]]
# Model summary: 225 layers, 3011628 parameters, 3011612 gradients, 8.2 GFLOPs
#
# Transferred 355/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /home/tham/Desktop/delete/EY/dataset/labelled-dataset/self-annot
# train: WARNING ⚠️ /home/tham/Desktop/delete/EY/dataset/labelled-dataset/self-annotated/train/images/tile_7_34_jpg.rf.2897f64136d5857faa97ee3bf2152195.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/tham/Desktop/delete/EY/dataset/labelled-dataset/self-annotated/train/images/tile_7_34_jpg.rf.6238380a8ca0bef808d16105806d6ae4.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/tham/Desktop/delete/EY/dataset/labelled-dataset/self-annotated/train/images/tile_7_34_jpg.rf.a07ac9ce5efe4d79a08cb956c08902be.jpg: 1 duplicate labels removed
# train: New cache created: /home/tham/Desktop/delete/EY/dataset/labelled-dataset/self-annotated/train/labels.cache
# val: Scanning /home/tham/Desktop/delete/EY/dataset/labelled-dataset/self-annotat
# val: New cache created: /home/tham/Desktop/delete/EY/dataset/labelled-dataset/self-annotated/valid/labels.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 512 train, 512 val
# Using 8 dataloader workers
# Logging results to runs/detect/train
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/20      2.17G      1.494      1.439      1.316        172        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         50        843      0.471      0.673       0.67      0.476
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/20      2.01G      1.094      1.171      1.117        201        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         50        843      0.716      0.662      0.758      0.582
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/20      2.36G       1.04      1.091      1.099        259        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         50        843      0.596      0.696      0.732      0.569
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/20      2.25G       1.04      1.066      1.092        204        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         50        843      0.676      0.672      0.738      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/20      2.06G      1.033      1.035      1.092        194        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         50        843      0.684      0.673      0.738      0.581
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/20      2.13G     0.9956      1.008      1.074        209        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         50        843      0.693      0.647       0.74      0.575
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/20      2.18G     0.9873      0.978      1.064        178        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         50        843      0.684      0.666      0.753       0.59
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/20       2.3G     0.9755     0.9751      1.069        186        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         50        843       0.65      0.671      0.721      0.549
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/20      2.17G     0.9775     0.9561      1.069        164        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         50        843      0.711      0.677      0.735      0.561
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/20         2G     0.9656      0.931      1.055        235        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         50        843      0.684      0.697      0.734      0.572
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/20       1.9G     0.9225     0.9654      1.044        178        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         50        843      0.745      0.682      0.767      0.596
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/20      1.86G     0.8962     0.9131      1.043         98        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         50        843      0.697      0.653      0.737      0.557
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/20      1.89G     0.8996       0.88      1.038        172        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         50        843      0.739      0.672      0.762      0.595
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/20      1.84G     0.8915     0.8661      1.034        107        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         50        843      0.649      0.724      0.749       0.59
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/20       1.8G     0.8525     0.8313      1.021         81        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         50        843      0.712      0.685      0.748      0.583
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/20      1.91G     0.8561     0.8062      1.007        110        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         50        843      0.707       0.65      0.724       0.55
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/20       1.8G     0.8547     0.8111      1.015        139        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         50        843      0.709      0.652      0.731      0.566
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/20      1.92G     0.8493     0.7996      1.012        110        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         50        843      0.735      0.659      0.751      0.589
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/20      1.83G     0.8317     0.7864      1.009        134        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         50        843      0.769      0.636      0.742      0.574
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/20      1.89G     0.8386     0.7909      1.011        109        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         50        843      0.692      0.666      0.746      0.568
#
# 20 epochs completed in 0.022 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 6.2MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 6.2MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.0.196 🚀 Python-3.8.10 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2070 Super, 7974MiB)
# Model summary (fused): 168 layers, 3006428 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         50        843      0.744      0.682      0.767      0.596
#                      0         50        567      0.808      0.901      0.932      0.787
#                      1         50        106      0.651      0.792      0.797      0.585
#                      2         50        118      0.668      0.669      0.726      0.612
#                      3         50         52       0.85      0.365      0.613      0.399
# Speed: 0.1ms preprocess, 1.2ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to runs/detect/train
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0, 1, 2, 3])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7fe544c8acd0>
# fitness: 0.6128324628945646
# keys: ['metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)']
# maps: array([    0.78656,     0.58534,     0.61169,      0.3993])
# names: {0: '0', 1: '1', 2: '2', 3: '3'}
# plot: True
# results_dict: {'metrics/precision(B)': 0.7441781779373736, 'metrics/recall(B)': 0.6821180631608624, 'metrics/mAP50(B)': 0.7668095626270187, 'metrics/mAP50-95(B)': 0.5957238962576252, 'fitness': 0.6128324628945646}
# save_dir: PosixPath('runs/detect/train')
# speed: {'preprocess': 0.10569095611572266, 'inference': 1.2398099899291992, 'loss': 0.0005197525024414062, 'postprocess': 0.8734512329101562}

# %%
os.rename('runs', 'fine-tune-on-self-annotated')

# %%
from ultralytics import YOLO

# yaml file of the training dataset
yaml_file = "dataset/labelled-dataset/experts/data.yaml"

# use COCO pretrained YOLOv8 models from Module 1 for transfer learning
model = YOLO(f"{os.getcwd()}/fine-tune-on-self-annotated/detect/train/weights/best.pt")
model.train(data=yaml_file, epochs=10, imgsz=512, plots=True)
# Out:
# New https://pypi.org/project/ultralytics/8.1.27 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.8.10 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2070 Super, 7974MiB)
# engine/trainer: task=detect, mode=train, model=/home/tham/Desktop/delete/EY/fine-tune-on-self-annotated/detect/train/weights/best.pt, data=dataset/labelled-dataset/experts/data.yaml, epochs=10, patience=50, batch=16, imgsz=512, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752092  ultralytics.nn.modules.head.Detect           [4, [64, 128, 256]]
# Model summary: 225 layers, 3011628 parameters, 3011612 gradients, 8.2 GFLOPs
#
# Transferred 355/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /home/tham/Desktop/delete/EY/dataset/labelled-dataset/experts/tr
# train: New cache created: /home/tham/Desktop/delete/EY/dataset/labelled-dataset/experts/train/labels.cache
# val: Scanning /home/tham/Desktop/delete/EY/dataset/labelled-dataset/experts/vali
# val: New cache created: /home/tham/Desktop/delete/EY/dataset/labelled-dataset/experts/valid/labels.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 512 train, 512 val
# Using 8 dataloader workers
# Logging results to runs/detect/train
# Starting training for 10 epochs...
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/10      1.83G      1.368      1.694      1.289         55        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         10        210      0.398      0.454      0.349      0.222
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/10      1.79G      1.339      1.524       1.27        102        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         10        210      0.411      0.439      0.358      0.233
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/10      1.75G      1.351      1.504      1.251         62        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         10        210      0.399      0.574      0.368      0.242
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/10      1.81G      1.339      1.466      1.253         84        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         10        210      0.401      0.549      0.361      0.236
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/10      1.82G      1.329      1.477      1.232         38        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         10        210      0.315      0.488      0.338      0.211
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/10      1.82G      1.282      1.335      1.203         47        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         10        210      0.307      0.588      0.334      0.209
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/10      1.79G      1.278      1.357      1.224         47        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         10        210      0.299      0.571      0.334       0.21
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/10      1.76G      1.265      1.295       1.18         76        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         10        210      0.321      0.588      0.343      0.213
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/10       1.8G      1.263      1.306      1.175         46        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         10        210      0.343      0.569      0.354      0.223
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/10       1.8G      1.231      1.302      1.186         61        512: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         10        210      0.329      0.467      0.353      0.222
#
# 10 epochs completed in 0.003 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 6.2MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 6.2MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.0.196 🚀 Python-3.8.10 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2070 Super, 7974MiB)
# Model summary (fused): 168 layers, 3006428 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         10        210      0.398      0.574      0.368      0.242
#                      0         10        150      0.617       0.78      0.698       0.42
#                      1         10         23      0.233      0.174        0.1     0.0667
#                      2         10         34      0.244      0.676      0.335      0.201
#                      3         10          3      0.499      0.667       0.34       0.28
# Speed: 0.1ms preprocess, 1.0ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to runs/detect/train
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0, 1, 2, 3])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7fe3da584400>
# fitness: 0.2545307959590762
# keys: ['metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)']
# maps: array([    0.42017,    0.066736,     0.20073,     0.28003])
# names: {0: '0', 1: '1', 2: '2', 3: '3'}
# plot: True
# results_dict: {'metrics/precision(B)': 0.3983325603025667, 'metrics/recall(B)': 0.5742625745950554, 'metrics/mAP50(B)': 0.36807025404650384, 'metrics/mAP50-95(B)': 0.2419153006160287, 'fitness': 0.2545307959590762}
# save_dir: PosixPath('runs/detect/train')
# speed: {'preprocess': 0.13539791107177734, 'inference': 1.0439872741699219, 'loss': 0.0012159347534179688, 'postprocess': 1.0242938995361328}
